# %%
import dd
import matplotlib.pyplot as plt
from getsig import getsig
from scipy.signal import medfilt
#
plt.style.use('helvet2')

# %%
lfsr = getsig(34622, 'RDL', 'LFSR')
# Out:
# /afs/ipp/aug/ads-diags/common/python/lib/dd_20180216.py:117: RuntimeWarning: Warning by DDcsgrp (8.1): No PARAM_SET found
#   warnings.warn(text.replace('\x00','').strip(), RuntimeWarning)

# %%
for i in range(5):
    plt.plot(lfsr.time, medfilt(lfsr.data[:,i],39))

plt.xlim(1,7)
plt.ylim(2.12,2.22)
plt.xlabel('time [s]')
plt.
plt.show()

# %%
plt.plot(lfsr.time, medfilt(lfsr.data[:,i],1))
plt.plot(lfsr.time, medfilt(lfsr.data[:,i],39))
plt.xlim(2,6)
plt.ylim(2.1,2.2)
plt.show()
