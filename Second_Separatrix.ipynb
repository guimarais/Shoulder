# %%
import matplotlib.pyplot as plt
import numpy as np
from rhosep2 import rhosep2
from scipy.signal import medfilt
plt.style.use('helvet2')

# %%
shotnr = 34875
ti = 1.0
tf = 7.0
npts = np.int((tf-ti)*1e3)+1
times = np.linspace(ti, tf, endpoint=True, num=npts)

# %%
rsp2 = rhosep2(shotnr, times, equil='GQH')

# %%
medpts = 11
plt.plot(times, medfilt(rsp2,medpts))
plt.ylim(0.99, 1.06)
plt.xlim(2.0, 8)
plt.show()
