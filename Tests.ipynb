# %%
from getsig import getsig
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('helvetpres2')

# %%
tdiv = getsig(35893, 'DDS', 'Tdiv')
# Out:
# /afs/ipp/aug/ads-diags/common/python/lib/dd.py:117: RuntimeWarning: Warning by DDcsgnl (8.1): no calibration of data
#   warnings.warn(text.replace('\x00','').strip(), RuntimeWarning)

# %%
plt.plot(tdiv.time, tdiv.data)
plt.show()

# %%
shotnr = 35893
ui = getsig(shotnr, 'LSD', 'te-ui4')
ua = getsig(shotnr, 'LSD', 'te-ua4')

# %%
plt.plot(ua.time, ua.data)
plt.show()
